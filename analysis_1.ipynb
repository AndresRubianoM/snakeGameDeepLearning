# %%
# %run analysis_functions.ipynb
# Out:
# pygame 1.9.6
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
SNAKE_GAMES = [SnakeAI([30,30], 3)]

# %%
REWARDS = [{
            'aprox': [1,0],
            'eat':[10,0],
            'dead':[-100, 0]
            },
            {
            'aprox': [1,0],
            'eat':[10,0],
            'dead':[-10, 0]
            },
            {
            'aprox': [1,-1],
            'eat':[10,0],
            'dead':[-100, 0]
            },
            {
            'aprox': [3,-1],
            'eat':[10,0],
            'dead':[-100, 0]
            },
            {
            'aprox': [1,0],
            'eat':[20,0],
            'dead':[-10, 0]
            },
            {
            'aprox': [3,-1],
            'eat':[20,0],
            'dead':[-10, 0]
            },
    ]

# %%
paths = paths_to_data(SNAKE_GAMES, REWARDS)

# %% [markdown]
# ## First Reward

# %% [markdown]
# ### Data from training

# %%
general_sample_visualization(paths, 0)
average_comparative(paths, 0)

# %% [markdown]
# ### Samples of each iteration

# %%
df_0 = samples_per_iteration(0,200)
histogram(df_0)

# %%
df_0.describe()
# Out:
#                   0            1            2
# count    200.000000   200.000000   200.000000
# mean    1919.370000  1407.450000  1395.250000
# std     2930.013493   480.573294   564.514776
# min      382.000000   415.000000   324.000000
# 25%     1130.750000  1078.250000   977.500000
# 50%     1435.000000  1360.000000  1356.500000
# 75%     1790.500000  1741.500000  1748.250000
# max    20168.000000  2799.000000  3184.000000

# %%
delete_outliers(df_0)
df_0.describe()
# Out:
#                  0            1            2
# count   195.000000   199.000000   197.000000
# mean   1457.579487  1400.457286  1369.934010
# std     480.589401   471.474398   529.561814
# min     382.000000   415.000000   324.000000
# 25%    1115.000000  1076.500000   976.000000
# 50%    1425.000000  1359.000000  1345.000000
# 75%    1744.000000  1736.500000  1729.000000
# max    2747.000000  2662.000000  2815.000000

# %% [markdown]
# ### Confidence interval

# %%
confidence_interval(df_0)
# Out:
#           left        right
# 0  1389.715255  1525.443719
# 1  1334.552701  1466.361872
# 2  1295.534924  1444.333097

# %% [markdown]
# ### Hypothesis test

# %%
test_means(0, df_0)
# Out:
#         Statistic   p_value
# 0_vs_1    1.19070  0.234493
# 0_vs_2    1.71624  0.086918

# %% [markdown]
# ## Second Reward

# %% [markdown]
# ### Data from training

# %%
general_sample_visualization(paths, 1)
average_comparative(paths, 1)

# %%
df_1 = samples_per_iteration(1,200)
histogram(df_1)

# %% [markdown]
# ### Samples of each iteration

# %%
df_1.describe()
# Out:
#                  0            1            2
# count   200.000000   200.000000   200.000000
# mean   1350.140000  1381.910000  1444.810000
# std     441.477989   379.304855   474.230775
# min     384.000000   427.000000   384.000000
# 25%    1012.000000  1128.000000  1099.250000
# 50%    1379.000000  1365.000000  1417.500000
# 75%    1660.750000  1629.500000  1736.000000
# max    2664.000000  2501.000000  2783.000000

# %%
delete_outliers(df_1)
df_1.describe()
# Out:
#                  0            1            2
# count   199.000000   199.000000   199.000000
# mean   1343.537688  1376.286432  1438.085427
# std     432.579516   371.809027   465.769265
# min     384.000000   427.000000   384.000000
# 25%    1011.000000  1128.000000  1097.500000
# 50%    1376.000000  1363.000000  1404.000000
# 75%    1655.500000  1617.000000  1733.500000
# max    2535.000000  2239.000000  2655.000000

# %% [markdown]
# ### Confidence interval

# %%
confidence_interval(df_1)
# Out:
#           left        right
# 0  1283.069986  1404.005391
# 1  1324.313473  1428.259392
# 2  1372.978328  1503.192526

# %% [markdown]
# ### Hypothesis test

# %%
test_means(2, df_1)
# Out:
#         Statistic   p_value
# 2_vs_0   2.098222  0.036522
# 2_vs_1   1.462790  0.144357

# %% [markdown]
# ## Third Reward

# %% [markdown]
# ### Data from training

# %%
general_sample_visualization(paths, 2)
average_comparative(paths, 2)

# %% [markdown]
# ### Samples of each iteration

# %%
df_2 = samples_per_iteration(2,200)
histogram(df_2)

# %%
df_2.describe()
# Out:
#                  0            1            2
# count   200.000000   200.000000   200.000000
# mean   1255.035000  1384.070000  1353.060000
# std     414.074343   452.016982   432.248342
# min     388.000000   429.000000   451.000000
# 25%     931.250000  1060.750000   996.500000
# 50%    1254.500000  1361.500000  1342.500000
# 75%    1514.500000  1671.250000  1656.750000
# max    2352.000000  2816.000000  2646.000000

# %%
delete_outliers(df_2)
df_2.describe()
# Out:
#                  0            1            2
# count   200.000000   198.000000   200.000000
# mean   1255.035000  1370.585859  1353.060000
# std     414.074343   433.616922   432.248342
# min     388.000000   429.000000   451.000000
# 25%     931.250000  1060.250000   996.500000
# 50%    1254.500000  1344.000000  1342.500000
# 75%    1514.500000  1664.000000  1656.750000
# max    2352.000000  2550.000000  2646.000000

# %% [markdown]
# ### Confidence interval

# %%
confidence_interval(df_2)
# Out:
#           left        right
# 0  1197.298909  1312.771091
# 1  1309.820274  1431.351443
# 2  1292.789833  1413.330167

# %% [markdown]
# ### Hypothesis test

# %%
test_means(0, df_2)
# Out:
#         Statistic   p_value
# 0_vs_1  -2.718353  0.006850
# 0_vs_2  -2.315958  0.021069

# %% [markdown]
# ## Fourth Reward

# %% [markdown]
# ### Data from training

# %%
general_sample_visualization(paths, 3)
average_comparative(paths, 3)

# %% [markdown]
# ### Samples of each iteration

# %%
df_3 = samples_per_iteration(3,200)
histogram(df_3)

# %%
df_3.describe()
# Out:
#                   0            1            2
# count    200.000000   200.000000   200.000000
# mean    4063.980000  3232.075000  3749.960000
# std     3936.748107  1130.750393  1051.354488
# min      986.000000   814.000000  1134.000000
# 25%     2623.750000  2509.250000  2986.500000
# 50%     3531.500000  3218.500000  3682.500000
# 75%     4389.750000  3890.500000  4446.500000
# max    30154.000000  6797.000000  6669.000000

# %%
delete_outliers(df_3)
df_3.describe()
# Out:
#                  0            1            2
# count   194.000000   196.000000   199.000000
# mean   3492.798969  3167.459184  3735.291457
# std    1205.248920  1045.879001  1033.285173
# min     986.000000   814.000000  1134.000000
# 25%    2596.750000  2506.750000  2985.000000
# 50%    3523.500000  3156.500000  3675.000000
# 75%    4312.250000  3814.500000  4425.000000
# max    6687.000000  5958.000000  6435.000000

# %% [markdown]
# ### Confidence interval

# %%
confidence_interval(df_3)
# Out:
#           left        right
# 0  3322.167181  3663.430757
# 1  3020.147408  3314.770959
# 2  3590.854705  3879.728210

# %% [markdown]
# ### Hypothesis test

# %%
test_means(0, df_2)
# Out:
#         Statistic   p_value
# 0_vs_1  -2.718353  0.006850
# 0_vs_2  -2.315958  0.021069

# %% [markdown]
# ## Fifth Reward

# %% [markdown]
# ### Data from training

# %%
general_sample_visualization(paths, 4)
average_comparative(paths, 4)

# %% [markdown]
# ### Samples of each iteration

# %%
df_4 = samples_per_iteration(4,200)
histogram(df_4)

# %%
df_4.describe()
# Out:
#                  0            1            2
# count   200.000000   200.000000   200.000000
# mean   1935.200000  2008.860000  1989.270000
# std     580.743545   553.748896   589.855946
# min     536.000000   694.000000   625.000000
# 25%    1500.250000  1661.000000  1547.500000
# 50%    1883.500000  1942.500000  1938.500000
# 75%    2360.250000  2323.500000  2416.750000
# max    3814.000000  3619.000000  3671.000000

# %%
delete_outliers(df_4)
df_4.describe()
# Out:
#                  0            1            2
# count   199.000000   197.000000   200.000000
# mean   1925.758794  1986.131980  1989.270000
# std     566.611951   525.843193   589.855946
# min     536.000000   694.000000   625.000000
# 25%    1499.500000  1655.000000  1547.500000
# 50%    1876.000000  1928.000000  1938.500000
# 75%    2354.500000  2317.000000  2416.750000
# max    3509.000000  3308.000000  3671.000000

# %% [markdown]
# ### Confidence interval

# %%
confidence_interval(df_4)
# Out:
#           left        right
# 0  1846.555499  2004.962089
# 1  1912.255329  2060.008631
# 2  1907.023956  2071.516044

# %% [markdown]
# ### Hypothesis test

# %%
test_means(2, df_4)
# Out:
#         Statistic   p_value
# 2_vs_0   1.096822  0.273385
# 2_vs_1   0.055971  0.955393

# %% [markdown]
# ## Fifth Reward

# %% [markdown]
# ### Data from training

# %%
general_sample_visualization(paths, 5)
average_comparative(paths, 5)

# %% [markdown]
# ### Samples of each iteration

# %%
df_5 = samples_per_iteration(5,200)
histogram(df_5)

# %%
df_5.describe()
# Out:
#                  0            1            2
# count   200.000000   200.000000   200.000000
# mean   3810.225000  3534.220000  4150.735000
# std    1192.215565  1100.924624  1188.836104
# min    1263.000000  1171.000000  1536.000000
# 25%    2846.750000  2649.750000  3314.750000
# 50%    3737.000000  3448.000000  4075.000000
# 75%    4599.750000  4423.250000  4939.750000
# max    6714.000000  6517.000000  7043.000000

# %%
delete_outliers(df_5)
df_5.describe()
# Out:
#                  0            1            2
# count   200.000000   200.000000   200.000000
# mean   3810.225000  3534.220000  4150.735000
# std    1192.215565  1100.924624  1188.836104
# min    1263.000000  1171.000000  1536.000000
# 25%    2846.750000  2649.750000  3314.750000
# 50%    3737.000000  3448.000000  4075.000000
# 75%    4599.750000  4423.250000  4939.750000
# max    6714.000000  6517.000000  7043.000000

# %% [markdown]
# ### Confidence interval

# %%
confidence_interval(df_5)
# Out:
#           left        right
# 0  3643.989473  3976.460527
# 1  3380.713545  3687.726455
# 2  3984.970685  4316.499315

# %% [markdown]
# ### Hypothesis test

# %%
test_means(0, df_5)
# Out:
#         Statistic   p_value
# 0_vs_1   2.405318  0.016617
# 0_vs_2  -2.860162  0.004457
